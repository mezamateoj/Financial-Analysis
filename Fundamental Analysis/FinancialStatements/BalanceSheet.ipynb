# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
balance_sheet = pd.read_excel('../FinancialStatements/Datasets/balance_sheet.xlsx')
balance_sheet.head()
# Out:
#    Year  Accounts Payable         Cash  Common Stock  \
# 0  2019       46236000000  48844000000  4.517400e+10
# 1  2020       42296000000  38016000000  5.077900e+10
# 2  2021       54763000000  34940000000  5.736500e+10
# 3  2022       64115000000  23646000000  6.484900e+10
# 4  2019        9382000000  11356000000  7.852000e+10
#
#    Gains Losses Not Affecting Retained Earnings     Inventory  Long Term Debt  \
# 0                                    -584000000  4.106000e+09    9.180700e+10
# 1                                    -406000000  4.061000e+09    9.866700e+10
# 2                                     163000000  6.580000e+09    1.091060e+11
# 3                                  -11109000000  4.946000e+09    9.895900e+10
# 4                                    -340000000  2.063000e+09    6.666200e+10
#
#    Long Term Investments  Net Receivables  Net Tangible Assets  ...  \
# 0           1.053410e+11      45804000000          90488000000  ...
# 1           1.008870e+11      37445000000          65339000000  ...
# 2           1.278770e+11      51506000000          63090000000  ...
# 3           1.208050e+11      60932000000          50672000000  ...
# 4           2.649000e+09      29524000000          52554000000  ...
#
#      Total Liab  Total Stockholder Equity  comp_type  company  \
# 0  248028000000               90488000000       tech     AAPL
# 1  258549000000               65339000000       tech     AAPL
# 2  287912000000               63090000000       tech     AAPL
# 3  302083000000               50672000000       tech     AAPL
# 4  184226000000              102330000000       tech     MSFT
#
#    Deferred Long Term Asset Charges     Good Will  Intangible Assets  \
# 0                               NaN           NaN                NaN
# 1                               NaN           NaN                NaN
# 2                               NaN           NaN                NaN
# 3                               NaN           NaN                NaN
# 4                      7.536000e+09  4.202600e+10       7.750000e+09
#
#    Capital Surplus  Minority Interest  Deferred Long Term Liab
# 0              NaN                NaN                      NaN
# 1              NaN                NaN                      NaN
# 2              NaN                NaN                      NaN
# 3              NaN                NaN                      NaN
# 4              NaN                NaN                      NaN
#
# [5 rows x 32 columns]

# %%
balance_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 32 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Year                                          60 non-null     int64
#  1   Accounts Payable                              60 non-null     int64
#  2   Cash                                          60 non-null     int64
#  3   Common Stock                                  57 non-null     float64
#  4   Gains Losses Not Affecting Retained Earnings  60 non-null     int64
#  5   Inventory                                     44 non-null     float64
#  6   Long Term Debt                                56 non-null     float64
#  7   Long Term Investments                         49 non-null     float64
#  8   Net Receivables                               60 non-null     int64
#  9   Net Tangible Assets                           60 non-null     int64
#  10  Other Assets                                  60 non-null     int64
#  11  Other Current Assets                          56 non-null     float64
#  12  Other Current Liab                            60 non-null     int64
#  13  Other Liab                                    60 non-null     int64
#  14  Other Stockholder Equity                      60 non-null     int64
#  15  Property Plant Equipment                      60 non-null     int64
#  16  Retained Earnings                             52 non-null     float64
#  17  Short Long Term Debt                          48 non-null     float64
#  18  Short Term Investments                        37 non-null     float64
#  19  Total Assets                                  60 non-null     int64
#  20  Total Current Assets                          60 non-null     int64
#  21  Total Current Liabilities                     60 non-null     int64
#  22  Total Liab                                    60 non-null     int64
#  23  Total Stockholder Equity                      60 non-null     int64
#  24  comp_type                                     60 non-null     object
#  25  company                                       60 non-null     object
#  26  Deferred Long Term Asset Charges              40 non-null     float64
#  27  Good Will                                     52 non-null     float64
#  28  Intangible Assets                             52 non-null     float64
#  29  Capital Surplus                               40 non-null     float64
#  30  Minority Interest                             32 non-null     float64
#  31  Deferred Long Term Liab                       8 non-null      float64
# dtypes: float64(14), int64(16), object(2)
# memory usage: 15.1+ KB

# %%
balance_sheet['current_ratio'] = balance_sheet['total_current_assets'] / balance_sheet['total_current_liab']
