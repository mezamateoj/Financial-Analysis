# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
balance_sheet = pd.read_excel('../FinancialStatements/Datasets/balance_sheet.xlsx')
balance_sheet.head()
# Out:
#    Year  Accounts Payable         Cash  Common Stock  \
# 0  2019       46236000000  48844000000  4.517400e+10
# 1  2020       42296000000  38016000000  5.077900e+10
# 2  2021       54763000000  34940000000  5.736500e+10
# 3  2022       64115000000  23646000000  6.484900e+10
# 4  2019        9382000000  11356000000  7.852000e+10
#
#    Gains Losses Not Affecting Retained Earnings     Inventory  Long Term Debt  \
# 0                                    -584000000  4.106000e+09    9.180700e+10
# 1                                    -406000000  4.061000e+09    9.866700e+10
# 2                                     163000000  6.580000e+09    1.091060e+11
# 3                                  -11109000000  4.946000e+09    9.895900e+10
# 4                                    -340000000  2.063000e+09    6.666200e+10
#
#    Long Term Investments  Net Receivables  Net Tangible Assets  ...  \
# 0           1.053410e+11      45804000000          90488000000  ...
# ...

# %%
balance_sheet.columns.values
# Out:
# array(['Year', 'Accounts Payable', 'Cash', 'Common Stock',
#        'Gains Losses Not Affecting Retained Earnings', 'Inventory',
#        'Long Term Debt', 'Long Term Investments', 'Net Receivables',
#        'Net Tangible Assets', 'Other Assets', 'Other Current Assets',
#        'Other Current Liab', 'Other Liab', 'Other Stockholder Equity',
#        'Property Plant Equipment', 'Retained Earnings',
#        'Short Long Term Debt', 'Short Term Investments', 'Total Assets',
#        'Total Current Assets', 'Total Current Liabilities', 'Total Liab',
#        'Total Stockholder Equity', 'comp_type', 'company',
#        'Deferred Long Term Asset Charges', 'Good Will',
#        'Intangible Assets', 'Capital Surplus', 'Minority Interest',
#        'Deferred Long Term Liab'], dtype=object)

# %%
balance_sheet['current_ratio'] = balance_sheet['Total Current Assets'] / balance_sheet['Total Current Liabilities']

# %%
balance_sheet.head()
# Out:
#    Year  Accounts Payable         Cash  Common Stock  \
# 0  2019       46236000000  48844000000  4.517400e+10
# 1  2020       42296000000  38016000000  5.077900e+10
# 2  2021       54763000000  34940000000  5.736500e+10
# 3  2022       64115000000  23646000000  6.484900e+10
# 4  2019        9382000000  11356000000  7.852000e+10
#
#    Gains Losses Not Affecting Retained Earnings     Inventory  Long Term Debt  \
# 0                                    -584000000  4.106000e+09    9.180700e+10
# 1                                    -406000000  4.061000e+09    9.866700e+10
# 2                                     163000000  6.580000e+09    1.091060e+11
# 3                                  -11109000000  4.946000e+09    9.895900e+10
# 4                                    -340000000  2.063000e+09    6.666200e+10
#
#    Long Term Investments  Net Receivables  Net Tangible Assets  Other Assets  \
# 0           1.053410e+11      45804000000          90488000000   32978000000
# ...

# %%
balance_sheet.groupby('comp_type')['current_ratio'].mean()
# Out:
# comp_type
# fmcg        0.868631
# real_est    1.025647
# tech        2.561735
# Name: current_ratio, dtype: float64

# %%
balance_sheet.groupby(['Year','comp_type'])['current_ratio'].mean()
# Out:
# Year  comp_type
# 2018  fmcg         0.894033
#       real_est     0.918590
#       tech         4.070359
# 2019  fmcg         0.801619
#       real_est     0.956540
#       tech         2.587904
# 2020  fmcg         0.958568
#       real_est     1.039277
#       tech         2.609484
# 2021  fmcg         0.868201
#       real_est     1.188182
#       tech         2.074543
# 2022  fmcg         0.654545
#       tech         1.331981
# Name: current_ratio, dtype: float64

# %%
# plot the current ratio by company type and year
plt.figure(figsize=(8, 5))
sns.barplot(x='comp_type', y='current_ratio', hue='Year', data=balance_sheet)
plt.title('Current Ratio by Company Type and Year')
plt.xlabel('Company Type')
plt.ylabel('Current Ratio')
plt.show()

# %%
balance_sheet['industry_current_ratio'] = balance_sheet.groupby(['Year', 'comp_type'])['current_ratio'].transform('mean')

# %%
balance_sheet[balance_sheet['company'] == 'AAPL'].head()
# Out:
#    Year  Accounts Payable         Cash  Common Stock  \
# 0  2019       46236000000  48844000000  4.517400e+10
# 1  2020       42296000000  38016000000  5.077900e+10
# 2  2021       54763000000  34940000000  5.736500e+10
# 3  2022       64115000000  23646000000  6.484900e+10
#
#    Gains Losses Not Affecting Retained Earnings     Inventory  Long Term Debt  \
# 0                                    -584000000  4.106000e+09    9.180700e+10
# 1                                    -406000000  4.061000e+09    9.866700e+10
# 2                                     163000000  6.580000e+09    1.091060e+11
# 3                                  -11109000000  4.946000e+09    9.895900e+10
#
#    Long Term Investments  Net Receivables  Net Tangible Assets  Other Assets  \
# 0           1.053410e+11      45804000000          90488000000   32978000000
# 1           1.008870e+11      37445000000          65339000000   33952000000
# ...

# %%
balance_sheet['relative_diff'] = (balance_sheet['current_ratio'] - balance_sheet['industry_current_ratio']) - 1

# %%
balance_sheet.head()
# Out:
#    Year  Accounts Payable         Cash  Common Stock  \
# 0  2019       46236000000  48844000000  4.517400e+10
# 1  2020       42296000000  38016000000  5.077900e+10
# 2  2021       54763000000  34940000000  5.736500e+10
# 3  2022       64115000000  23646000000  6.484900e+10
# 4  2019        9382000000  11356000000  7.852000e+10
#
#    Gains Losses Not Affecting Retained Earnings     Inventory  Long Term Debt  \
# 0                                    -584000000  4.106000e+09    9.180700e+10
# 1                                    -406000000  4.061000e+09    9.866700e+10
# 2                                     163000000  6.580000e+09    1.091060e+11
# 3                                  -11109000000  4.946000e+09    9.895900e+10
# 4                                    -340000000  2.063000e+09    6.666200e+10
#
#    Long Term Investments  Net Receivables  Net Tangible Assets  Other Assets  \
# 0           1.053410e+11      45804000000          90488000000   32978000000
# ...

# %%
balance_sheet[balance_sheet['relative_diff'] > 0]
# Out:
#     Year  Accounts Payable         Cash  Common Stock  \
# 16  2018         820000000  10019000000  4.290600e+10
# 17  2019        1363000000  19079000000           NaN
# 18  2020        1331000000  17576000000           NaN
# 19  2021        4083000000  16601000000           NaN
# 39  2021         281000000   1879000000  9.340000e+08
#
#     Gains Losses Not Affecting Retained Earnings    Inventory  Long Term Debt  \
# 16                                    -760000000          NaN             NaN
# 17                                    -489000000          NaN             NaN
# 18                                     927000000          NaN             NaN
# 19                                    -693000000          NaN             NaN
# 39                                    7702000000  520000000.0    5.099000e+09
#
#     Long Term Investments  Net Receivables  Net Tangible Assets  Other Assets  \
# 16                    NaN       7587000000          64532000000    2576000000
# ...

# %%
# Fast-moving consumer goods and tech for 2020 and 2019
data = balance_sheet.loc[
    (balance_sheet['Year'].isin([2019, 2020])) & (balance_sheet['comp_type'].isin(['tech', 'fmcg']))]

# %%
data
# Out:
#     Year  Accounts Payable         Cash  Common Stock  \
# 0   2019       46236000000  48844000000  4.517400e+10
# 1   2020       42296000000  38016000000  5.077900e+10
# 4   2019        9382000000  11356000000  7.852000e+10
# 5   2020       12530000000  13576000000  8.055200e+10
# 9   2019        5561000000  18498000000  5.055200e+10
# 10  2020        5589000000  26465000000  5.851000e+10
# 13  2019       47183000000  36092000000  5.000000e+06
# 14  2020       72539000000  42122000000  5.000000e+06
# 17  2019        1363000000  19079000000           NaN
# 18  2020        1331000000  17576000000           NaN
# 41  2019       14017000000   7469000000  2.980000e+08
# 42  2020       13802000000   5235000000  2.880000e+08
# 44  2019       11260000000   4239000000  4.009000e+09
# 45  2020       12071000000  16181000000  4.009000e+09
# 49  2019        8013000000   5509000000  2.300000e+07
# 50  2020        8853000000   8185000000  2.300000e+07
# ...
