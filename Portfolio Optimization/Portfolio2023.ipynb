# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import PortfolioConfig
import datetime
import seaborn as sns

# %%
df = pd.read_json('../data.json')
df.head(10)
# Out:
#                                            Meta Data  \
# 0  {'1. Information': 'Daily Time Series with Spl...
# 1  {'1. Information': 'Daily Time Series with Spl...
# 2  {'1. Information': 'Daily Time Series with Spl...
# 3  {'1. Information': 'Daily Time Series with Spl...
# 4  {'1. Information': 'Daily Time Series with Spl...
# 5                                                NaN
# 6                                                NaN
#
#                                  Time Series (Daily)  \
# 0  {'2023-04-21': {'1. open': '315.91', '2. high'...
# 1  {'2023-04-21': {'1. open': '204.96', '2. high'...
# 2  {'2023-04-21': {'1. open': '89.8', '2. high': ...
# 3  {'2023-04-21': {'1. open': '327.29', '2. high'...
# 4  {'2023-04-21': {'1. open': '224.61', '2. high'...
# 5                                                NaN
# 6                                                NaN
#
#                                                 Note
# 0                                                NaN
# ...

# %%
df.T
# Out:
#                                                                      0  \
# Meta Data            {'1. Information': 'Daily Time Series with Spl...
# Time Series (Daily)  {'2023-04-21': {'1. open': '315.91', '2. high'...
# Note                                                               NaN
#
#                                                                      1  \
# Meta Data            {'1. Information': 'Daily Time Series with Spl...
# Time Series (Daily)  {'2023-04-21': {'1. open': '204.96', '2. high'...
# Note                                                               NaN
#
#                                                                      2  \
# Meta Data            {'1. Information': 'Daily Time Series with Spl...
# Time Series (Daily)  {'2023-04-21': {'1. open': '89.8', '2. high': ...
# Note                                                               NaN
#
#                                                                      3  \
# ...
